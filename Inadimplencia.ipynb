# %%
import pandas as pd
import matplotlib as plt

# %%
arq= pd.read_csv(r'C:\Users\leticia.santos\Documents\Tryingdo\STP-20230105101319492.csv', encoding='latin-1', sep= ';')

# %%
arq
# Out:
#        Data 21082 - Inadimplência da carteira de crédito - Total - %  \
# 0    mar/11                                               3,17
# 1    abr/11                                               3,24
# 2    mai/11                                               3,37
# 3    jun/11                                               3,32
# 4    jul/11                                               3,42
# ..      ...                                                ...
# 136  jul/22                                               2,78
# 137  ago/22                                               2,83
# 138  set/22                                                2,9
# 139  out/22                                                  3
# 140  nov/22                                               3,06
#
#     21083 - Inadimplência da carteira de crédito - Pessoas jurídicas - Total - %  \
# 0                                                 1,96
# 1                                                 2,04
# ...
